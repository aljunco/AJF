# %% [markdown]
# Actividad A5
# Alejandro Junco//A00828426

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           cwurData.csv   pokemon.csv
# antropometria00.csv        data.csv       sample_pivot.csv
# antropometria-dataset.csv  headbrain.csv  tips.csv
# Canada.xlsx                mic.xlsx       weight-height.csv
# Cartwheeldata.csv          movies.csv

# %%
df = pd.read_csv('datasets/antropometria-dataset.csv')

# %%
plt.boxplot(df['edad'], whis=(0, 100))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1456503970>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f1456510070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1456503610>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1456510730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1456510a30>],
#  'means': []}

# %%
plt.boxplot(df['peso'], whis=(0, 100))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f145323a310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f145323a9d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f145322df70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f14532460d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f14532463d0>],
#  'means': []}

# %%
plt.plot(df['cintura'])

# %%
plt.plot(df['peso'])

# %%
plt.hist(df['cintura'])
# Out:
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([1.000e+00, 5.000e+01, 4.094e+03, 8.601e+03, 4.683e+03, 5.180e+02,
#         3.200e+01, 6.000e+00, 0.000e+00, 4.700e+01]),
#  array([ 11.9  ,  32.932,  53.964,  74.996,  96.028, 117.06 , 138.092,
#         159.124, 180.156, 201.188, 222.22 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['peso'])
# Out:
# (array([6.030e+02, 2.583e+03, 6.160e+03, 5.685e+03, 2.615e+03, 7.730e+02,
#         1.540e+02, 4.600e+01, 1.600e+01, 5.000e+00]),
#  array([ 18.  ,  33.26,  48.52,  63.78,  79.04,  94.3 , 109.56, 124.82,
#         140.08, 155.34, 170.6 ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(df['peso'], df['cintura'])

# %% [markdown]
# 1. Tanto los histogramas como los boxplots están sesgados hacia la izquiera
# 2. En ambos histogramas se pueden observar valores atipicos
# 3.
