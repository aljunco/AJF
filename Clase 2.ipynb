# %% [markdown]
# # Clase 2: Tipos de datos

# %%
import numpy as np

# %%
type(3)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
type(3/5)
# Out:
# float

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
import math

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## listas

# %%
una_lista = [1,3/5,'nombre',True,5<=3,1==3,3==3,None]
una_lista
# Out:
# [1, 0.6, 'nombre', True, False, False, True, None]

# %%
str_lista = ['first','second','third','fouth','fifth','sixth']
str_lista
# Out:
# ['first', 'second', 'third', 'fouth', 'fifth', 'sixth']

# %%
str_lista.sort()
str_lista
# Out:
# ['fifth', 'first', 'fouth', 'second', 'sixth', 'third']

# %%
numbers = [11,20,3,14,53,61]
numbers
# Out:
# [11, 20, 3, 14, 53, 61]

# %%
numbers[5]
# Out:
# 61

# %%
numbers[-1]
# Out:
# 61

# %%
numbers[:3]
# Out:
# [11, 20, 3]

# %%
numbers[1:3]
# Out:
# [20, 3]

# %%
numbers[3:]
# Out:
# [14, 53, 61]

# %%
x = sum(numbers)
x
# Out:
# 162

# %%
y = len(numbers)
y
# Out:
# 6

# %%
promedio = x/y
promedio
# Out:
# 27.0

# %% [markdown]
# # Una For Loop

# %%
numbers
# Out:
# [11, 20, 3, 14, 53, 61]

# %%
for i in numbers:
    print(i,   '\t\t', type(i))
# Out:
# 11 		 <class 'int'>
# 20 		 <class 'int'>
# 3 		 <class 'int'>
# 14 		 <class 'int'>
# 53 		 <class 'int'>
# 61 		 <class 'int'>

# %%
for i in una_lista:
    print(i,   '\t\t', type(i))
# Out:
# 1 		 <class 'int'>
# 0.6 		 <class 'float'>
# nombre 		 <class 'str'>
# True 		 <class 'bool'>
# False 		 <class 'bool'>
# False 		 <class 'bool'>
# True 		 <class 'bool'>
# None 		 <class 'NoneType'>

# %%
x = 6
y = 11
if x < y:
    print('{} es mayor que {}'.format(x,y))
else:
    print('{} es menor que {}'.format(x,y))
# Out:
# 6 es mayor que 11
